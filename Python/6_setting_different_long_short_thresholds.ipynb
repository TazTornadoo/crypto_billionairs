# %%
import pandas as pd
import numpy as np
from data_storage import create_connection
import matplotlib.pyplot as plt

# %%
#this notebook anaylzes the change of the risk-adjusted performance measures 
#by setting different thresholds and plots the changes for a long and short strategy

# %%
connection = create_connection("../database/crypto_billionairs.db")

# %%
sql = 'SELECT table_name'\
        ', annualized_return as annualized_return'\
        ', annualized_return / trades_count AS ann_return_per_trade'\
        ', win_rate AS win_rate'\
        ', sharpe_ratio_annualized as sharpe_ratio'\
        ', sortino_ratio_annualized as sortino_ratio'\
        ', maximum_drawdown as maximum_drawdown'\
        ', calmar_ratio_annualized as calmar_ratio'\
        ' FROM cryptocurrencies_risk_metrics_1m_abnormal_day_ml_threshold'\
        ' where timehorizon >= 365'
       

df = pd.read_sql_query(f"{sql}", connection)
df.head()
# Out:
#                           table_name  annualized_return  ann_return_per_trade  \
# 0  no_0_threshold_ensemble_long_ADA_          12.051090              0.033017
# 1  no_0_threshold_ensemble_long_BCH_          -3.413077             -0.005670
# 2  no_0_threshold_ensemble_long_BSV_          -7.517525             -0.020653
# 3  no_0_threshold_ensemble_long_BTC_           2.249213              0.001546
# 4  no_0_threshold_ensemble_long_BTG_          -3.692927             -0.005976
#
#     win_rate  sharpe_ratio  sortino_ratio  maximum_drawdown  calmar_ratio
# 0  53.150685     20.850254       2.526250         -0.207492      5.862978
# 1  50.000000    -12.151466      -1.766080         -0.889355     -0.953379
# 2  47.802198    -11.375123      -1.561076         -0.679517     -1.106305
# 3  52.439863     28.903735       2.595201         -0.799659      1.579206
# 4  49.190939    -14.205675      -1.978204         -0.960893     -0.989716

# %%
df["threshold"] = df["table_name"].str.split("_").str[1].astype(int)
df["type"] = df["table_name"].str.split("_").str[4]
df = df.drop(["table_name"], axis = 1)

# %%
df_plt = df.groupby(by=["type", "threshold"]).mean()

# %%
df_plt.xs("long")
# Out:
#            annualized_return  ann_return_per_trade   win_rate  sharpe_ratio  \
# threshold
# 0                  10.809947              0.050833  49.770152      3.647240
# 1                  10.809947              0.050833  49.770152      3.647240
# 2                  10.809947              0.050833  49.770152      3.647240
# 3                  10.809947              0.050833  49.770152      3.647240
# 4                  10.809947              0.050833  49.770152      3.647240
# 5                  10.809947              0.050833  49.770152      3.647240
# 6                  10.809947              0.050833  49.770152      3.647240
# 7                  10.997554              0.051191  49.791051      4.512640
# 8                  14.948603              0.070324  49.931150      4.188361
# 9                  30.066180              0.146981  49.363708      7.779824
# 10                 27.944927              0.141081  49.405455      4.623550
# 11                 17.381753              0.091357  49.591330      0.683992
# 12                 33.977663              0.188479  50.237775      6.066693
# 13                 18.597672              0.110946  49.894766     -0.543294
# 14                 11.965107              0.080107  48.569298     -2.982446
# 15                  8.068628              0.061921  49.290745     -2.648871
# 16                 -4.757870             -0.041032  48.821093     -4.439602
# 17                 -6.393050             -0.064995  46.479120     -7.121644
# 18                 -7.891146             -0.103025  45.891298     -6.691426
# 19                 -9.022672             -0.183092  41.736332     -8.023919
# 20                 -9.911505             -0.306263  37.377449     -7.148719
# 21                 -8.630672             -0.437141  36.219880     -5.612406
# 22                 -5.725570             -0.402814  36.841190     -3.194631
# 23                 -4.141476             -0.289228  36.661340     -2.375919
# 24                 -1.717391             -0.129204  39.525930     -0.671488
# 25                 -3.006584             -0.430045  38.093167     -2.515120
# 26                 -1.097494             -0.165935  39.809322     -1.510213
# 27                 -1.430286             -0.122661  39.279348     -2.561545
# 28                 -1.179644             -0.166745  34.726190     -3.570435
# 29                 -1.311252             -0.608613  31.666667     -2.378202
# 30                 -0.606614             -0.253367  31.349206     -2.208169
# 31                 -0.473143             -0.388772  30.833333     -1.863535
# 32                 -0.457604             -0.869997   0.000000     -2.172995
# 33                  0.000000                   NaN        NaN      0.000000
# 34                  0.000000                   NaN        NaN      0.000000
# 35                  0.000000                   NaN        NaN      0.000000
# 36                  0.000000                   NaN        NaN      0.000000
# 37                  0.000000                   NaN        NaN      0.000000
# 38                  0.000000                   NaN        NaN      0.000000
# 39                  0.000000                   NaN        NaN      0.000000
# 40                  0.000000                   NaN        NaN      0.000000
# 41                  0.000000                   NaN        NaN      0.000000
# 42                  0.000000                   NaN        NaN      0.000000
# 43                  0.000000                   NaN        NaN      0.000000
# 44                  0.000000                   NaN        NaN      0.000000
# 45                  0.000000                   NaN        NaN      0.000000
# 46                  0.000000                   NaN        NaN      0.000000
# 47                  0.000000                   NaN        NaN      0.000000
# 48                  0.000000                   NaN        NaN      0.000000
# 49                  0.000000                   NaN        NaN      0.000000
#
#            sortino_ratio  maximum_drawdown  calmar_ratio
# threshold
# 0               0.468166         -0.671466      2.474279
# 1               0.468166         -0.671466      2.474279
# 2               0.468166         -0.671466      2.474279
# 3               0.468166         -0.671466      2.474279
# 4               0.468166         -0.671466      2.474279
# 5               0.468166         -0.671466      2.474279
# 6               0.468166         -0.671466      2.474279
# 7               0.566378         -0.672778      2.525765
# 8               0.536099         -0.672115      5.456567
# 9               1.205367         -0.614333      6.903814
# 10              0.755513         -0.705628      1.919442
# 11              0.009334         -0.766158      0.665608
# 12              0.781925         -0.725613      0.732936
# 13             -0.153671         -0.824622      4.693348
# 14             -0.549858         -0.827702      0.981227
# 15             -0.455515         -0.837910      0.199882
# 16             -0.880561         -0.799840      0.254607
# 17             -1.272353         -0.794263     -0.420273
# 18             -1.330255         -0.796861      0.249624
# 19             -1.624030         -0.806436     -0.800178
# 20             -1.463755         -0.767740     -0.759353
# 21             -1.291008         -0.603993     -0.973466
# 22             -0.679808         -0.492103    136.066455
# 23             -0.383641         -0.474896      0.011187
# 24             -0.074329         -0.412276      0.548102
# 25             -0.467553         -0.355522      0.049663
# 26             -0.164766         -0.309166   4099.319745
# 27             -0.997064         -0.283500     -0.709041
# 28             -2.340271         -0.254585      0.809461
# 29             -1.913289         -0.216689    283.636130
# 30             -1.709594         -0.164252     -0.277861
# 31             -1.317899         -0.101337     -0.522593
# 32             -2.172995         -0.072657     -0.628604
# 33              0.000000          0.000000      0.000000
# 34              0.000000          0.000000      0.000000
# 35              0.000000          0.000000      0.000000
# 36              0.000000          0.000000      0.000000
# 37              0.000000          0.000000      0.000000
# 38              0.000000          0.000000      0.000000
# 39              0.000000          0.000000      0.000000
# 40              0.000000          0.000000      0.000000
# 41              0.000000          0.000000      0.000000
# 42              0.000000          0.000000      0.000000
# 43              0.000000          0.000000      0.000000
# 44              0.000000          0.000000      0.000000
# 45              0.000000          0.000000      0.000000
# 46              0.000000          0.000000      0.000000
# 47              0.000000          0.000000      0.000000
# 48              0.000000          0.000000      0.000000
# 49              0.000000          0.000000      0.000000

# %%
plt.rcParams["figure.figsize"] = (12, 5.5)
plt.subplot(1, 2, 1) # row 1, col 2 index 1
plt.plot(np.arange(0, len(df_plt.xs("long") + 1) * 0.02, 0.02), df_plt.xs("long")["annualized_return"])
plt.title("Long return (ann.)")
plt.xlabel("Threshold")
plt.ylabel("Return (ann.)") 

plt.subplot(1, 2, 2) # index 2
plt.plot(np.arange(0, len(df_plt.xs("short") + 1) * 0.02, 0.02), df_plt.xs("short")["annualized_return"])
plt.title("Short return (ann.)")
plt.xlabel("Threshold")
plt.ylabel("Return (ann.)")
# Out:
# Text(0, 0.5, 'Return (ann.)')

# %%
plt.subplot(1, 2, 1)
plt.plot(np.arange(0, len(df_plt.xs("long") + 1) * 0.02, 0.02), df_plt.xs("long")["sharpe_ratio"])
plt.title("Long Threshold")
plt.xlabel("Threshold")
plt.ylabel("Sharpe Ratio") 

plt.subplot(1, 2, 2) # index 2
plt.plot(np.arange(0, len(df_plt.xs("short") + 1) * 0.02, 0.02), df_plt.xs("short")["sharpe_ratio"])
plt.title("Short Threshold")
plt.xlabel("Threshold")
plt.ylabel("Sharpe Ratio")
# Out:
# Text(0, 0.5, 'Sharpe Ratio')

# %%
plt.subplot(1, 2, 1) # row 1, col 2 index 1
plt.plot(np.arange(0, len(df_plt.xs("long") + 1) * 0.02, 0.02), df_plt.xs("long")["sortino_ratio"])
plt.title("Long Threshold")
plt.xlabel("Threshold")
plt.ylabel("Sortino Ratio") 

plt.subplot(1, 2, 2) # index 2
plt.plot(np.arange(0, len(df_plt.xs("short") + 1) * 0.02, 0.02), df_plt.xs("short")["sortino_ratio"])
plt.title("Short Threshold")
plt.xlabel("Threshold")
plt.ylabel("Sortino Ratio")
# Out:
# Text(0, 0.5, 'Sortino Ratio')

# %%
plt.subplot(1, 2, 1) # row 1, col 2 index 1
plt.plot(np.arange(0, len(df_plt.xs("long") + 1) * 0.02, 0.02), df_plt.xs("long")["maximum_drawdown"])
plt.title("Long Threshold")
plt.xlabel("Threshold")
plt.ylabel("Maximum Drawdown") 

plt.subplot(1, 2, 2) # index 2
plt.plot(np.arange(0, len(df_plt.xs("short") + 1) * 0.02, 0.02), df_plt.xs("short")["maximum_drawdown"])
plt.title("Short Threshold")
plt.xlabel("Threshold")
plt.ylabel("Maximum Drawdown")
# Out:
# Text(0, 0.5, 'Maximum Drawdown')

# %%
plt.subplot(1, 2, 1) # row 1, col 2 index 1
plt.plot(np.arange(0, len(df_plt.xs("long") + 1) * 0.02, 0.02), df_plt.xs("long")["calmar_ratio"])
plt.title("Long Threshold")
plt.xlabel("Threshold")
plt.ylabel("Calmar Ratio") 

plt.subplot(1, 2, 2) # index 2
plt.plot(np.arange(0, len(df_plt.xs("short") + 1) * 0.02, 0.02), df_plt.xs("short")["calmar_ratio"])
plt.title("Short Threshold")
plt.xlabel("Threshold")
plt.ylabel("Calmar Ratio")
# Out:
# Text(0, 0.5, 'Calmar Ratio')

# %%
plt.subplot(1, 2, 1) # row 1, col 2 index 1
plt.plot(np.arange(0, len(df_plt.xs("long") + 1) * 0.02, 0.02), df_plt.xs("long")["win_rate"])
plt.title("Long Threshold")
plt.xlabel("Threshold")
plt.ylabel("Win Rate") 

plt.subplot(1, 2, 2) # index 2
plt.plot(np.arange(0, len(df_plt.xs("short") + 1) * 0.02, 0.02), df_plt.xs("short")["win_rate"])
plt.title("Short Threshold")
plt.xlabel("Threshold")
plt.ylabel("Win Rate")
# Out:
# Text(0, 0.5, 'Maximum Drawdown')
