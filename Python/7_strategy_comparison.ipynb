# %%
import pandas as pd
import numpy as np
from data_storage import create_connection
from risk_metrics import Risk_Metrics
import matplotlib.pyplot as plt
import os

# %%
connection = create_connection("../database/crypto_billionairs.db")

# %%
#Reproduction approach chapter 4.1
#an average of the backtest results across all cryptocurrencies for each model
df = pd.read_sql_query("select * from cryptocurrencies_risk_metrics_1m_abnormal_day_ml", connection)
df["aggregation_filter"] = df["table_name"].str.split("_").str[-1]
df.iloc[:, 5:].groupby(by=["aggregation_filter"]).mean()
# Out:
#                     annualized_return  sharpe_ratio_annualized  \
# aggregation_filter
# forest                     -38.448216                -4.875326
# knn                        -23.118746                -2.331430
# mlp                        -22.202717                -3.557415
# regression                 -27.209977                -3.993817
# svc                         -3.469999                -0.488305
#
#                     sortino_ratio_annualized  maximum_drawdown  \
# aggregation_filter
# forest                             -0.825623         -0.591493
# knn                                -0.506407         -0.536166
# mlp                                -0.479477         -0.487540
# regression                         -0.580310         -0.621212
# svc                                -0.083901         -0.559808
#
#                     calmar_ratio_annualized  trades_count   win_rate
# aggregation_filter
# forest                            -0.366828     70.541667  47.168992
# ...

# %%
#Reproduction approach chapter 4.2
#an average of the backtest results across all cryptocurrencies for each model trained on oversampled data
df = pd.read_sql_query("select * from cryptocurrencies_risk_metrics_1m_abnormal_day_ml_oversampling", connection)
df["aggregation_filter"] = df["table_name"].str.split("_").str[-2]
df.iloc[:, 5:].groupby(by=["aggregation_filter"]).mean()
# Out:
#                     annualized_return  sharpe_ratio_annualized  \
# aggregation_filter
# forest                      -8.192278                -2.070210
# knn                         -5.882954                -0.894949
# mlp                        -17.980955                -2.673135
# regression                  -7.132158                -1.956170
# svc                         -9.776846                -2.882715
#
#                     sortino_ratio_annualized  maximum_drawdown  \
# aggregation_filter
# forest                             -0.181339         -0.557343
# knn                                -0.135257         -0.554373
# mlp                                -0.394154         -0.606504
# regression                         -0.185150         -0.637019
# svc                                -0.251028         -0.542365
#
#                     calmar_ratio_annualized  trades_count   win_rate
# aggregation_filter
# forest                             1.461144     73.956522  46.131442
# ...

# %%
#Reproduction approach chapter 4.3
#an average of the backtest results across all cryptocurrencies for each model trained on pooled data
df = pd.read_sql_query("select * from cryptocurrencies_risk_metrics_1m_abnormal_day_ml_pooling", connection)
df["aggregation_filter1"] = df["table_name"].str.split("_").str[-3]
df["aggregation_filter2"] = df["table_name"].str.split("_").str[-2]
df.iloc[:, 5:].groupby(by=["aggregation_filter1", "aggregation_filter2"]).mean()
# Out:
#                                          annualized_return  \
# aggregation_filter1 aggregation_filter2
# features            ensemble                     -1.161394
#                     knn                           0.746905
# logistic            regression                   -5.338691
# mlp                 classifier                   -2.373367
# random              forest                       52.768210
# vector              classifier                   -3.009583
#
#                                          sharpe_ratio_annualized  \
# aggregation_filter1 aggregation_filter2
# features            ensemble                            0.271326
#                     knn                                -0.135055
# logistic            regression                         -0.277508
# mlp                 classifier                         -0.264079
# random              forest                              5.640362
# vector              classifier                         -0.973977
#
# ...

# %%
#Reproduction approach chapter 4.3.3
#an average of the backtest results across all cryptocurrencies setting a probability threshold manually
df = pd.read_sql_query("select * from cryptocurrencies_risk_metrics_1m_abnormal_day_ml_final", connection)
df["aggregation_filter"] = df["table_name"].str.split("_").str[0]
df.iloc[:, 5:].groupby(by=["aggregation_filter"]).mean()
# Out:
#                     annualized_return  sharpe_ratio_annualized  \
# aggregation_filter
# ensemble                   -39.650987                -4.348938
#
#                     sortino_ratio_annualized  maximum_drawdown  \
# aggregation_filter
# ensemble                           -0.856433         -0.608182
#
#                     calmar_ratio_annualized  trades_count   win_rate
# aggregation_filter
# ensemble                          -0.540324     83.541667  45.940545

# %%
#Reproduction approach chapter 4.4
#an average of the backtest results across all cryptocurrencies applying the heuristic
df = pd.read_sql_query("select * from cryptocurrencies_risk_metrics_1m_abnormal_day", connection)
df["aggregation_filter"] = df["table_name"].str.split("_").str[-1]
df.iloc[:, 4:].groupby(by=["aggregation_filter"]).mean()
# Out:
#                     buy and hold return  annualized_return  \
# aggregation_filter
# features                      -4.149289          21.949177
#
#                     sharpe_ratio_annualized  sortino_ratio_annualized  \
# aggregation_filter
# features                           3.241295                  0.423412
#
#                     maximum_drawdown  calmar_ratio_annualized  trades_count  \
# aggregation_filter
# features                   -0.286492                  4.83775          37.2
#
#                      win_rate
# aggregation_filter
# features            54.403908

# %%
df = pd.read_sql_query("select * from cryptocurrencies_risk_metrics_1m_abnormal_day_ml_pooling_reversal", connection)
df["aggregation_filter1"] = df["table_name"].str.split("_").str[-3]
df["aggregation_filter2"] = df["table_name"].str.split("_").str[-2]
df.iloc[:, 5:].groupby(by=["aggregation_filter1", "aggregation_filter2"]).mean()
# Out:
#                                          annualized_return  \
# aggregation_filter1 aggregation_filter2
# features            ensemble                     -6.166433
#                     knn                          -0.721220
# logistic            regression                  -14.121119
# mlp                 classifier                  -24.495958
# random              forest                       33.161199
# vector              classifier                  -29.411899
#
#                                          sharpe_ratio_annualized  \
# aggregation_filter1 aggregation_filter2
# features            ensemble                           -0.075439
#                     knn                                 0.419867
# logistic            regression                         -1.050516
# mlp                 classifier                         -2.523607
# random              forest                              4.436787
# vector              classifier                         -3.894891
#
# ...
